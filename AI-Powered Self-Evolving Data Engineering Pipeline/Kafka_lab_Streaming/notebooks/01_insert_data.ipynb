# %%
from kafka import KafkaConsumer
import json
import base64

consumer = KafkaConsumer(
    "dbserver1.testdb.orders",
    bootstrap_servers="kafka:9092",
    auto_offset_reset="earliest",
    value_deserializer=lambda x: json.loads(x.decode("utf-8"))
)
def decode_amount(value):
    try:
        decoded = base64.b64decode(value)
        return int.from_bytes(decoded, byteorder='big')
    except:
        return 0

for msg in consumer:
    data = msg.value

    payload = data.get("payload")

    print("DEBUG payload:", payload)   

    if payload is None:
        continue

    op = payload.get("op")

    after = payload.get("after")
    print("DEBUG op:", op)   

    if op == "c":
        print("INSERT:", payload.get("after"))

    elif op == "u":
        print("UPDATE:", payload.get("after"))

    elif op == "d":
        print("DELETE:", payload.get("before"))
    if after: 
        # High value alert
        amount = decode_amount(after.get("amount"))
        if amount > 50000:
            print("🚨 HIGH VALUE ORDER ALERT:", after)

        # Status summary
        print(f"[SUMMARY] Order {after['order_id']} is {after['status']}")

        # Customer stream
        print(f"[CUSTOMER STREAM] Customer {after['customer_id']} activity")
# Out:
# DEBUG payload: {'before': None, 'after': {'order_id': 1, 'customer_id': 101, 'product_name': 'Laptop', 'amount': 'cnDg', 'status': 'Placed', 'created_at': '2026-04-20T11:01:54Z', 'updated_at': '2026-04-20T11:01:54Z'}, 'source': {'version': '2.5.4.Final', 'connector': 'mysql', 'name': 'dbserver1', 'ts_ms': 1776682914000, 'snapshot': 'false', 'db': 'testdb', 'sequence': None, 'table': 'orders', 'server_id': 1, 'gtid': None, 'file': 'mysql-bin.000006', 'pos': 852, 'row': 0, 'thread': 12, 'query': None}, 'op': 'c', 'ts_ms': 1776682915086, 'transaction': None}
# DEBUG op: c
# INSERT: {'order_id': 1, 'customer_id': 101, 'product_name': 'Laptop', 'amount': 'cnDg', 'status': 'Placed', 'created_at': '2026-04-20T11:01:54Z', 'updated_at': '2026-04-20T11:01:54Z'}
# 🚨 HIGH VALUE ORDER ALERT: {'order_id': 1, 'customer_id': 101, 'product_name': 'Laptop', 'amount': 'cnDg', 'status': 'Placed', 'created_at': '2026-04-20T11:01:54Z', 'updated_at': '2026-04-20T11:01:54Z'}
# [SUMMARY] Order 1 is Placed
# [CUSTOMER STREAM] Customer 101 activity
# DEBUG payload: {'before': None, 'after': {'order_id': 2, 'customer_id': 102, 'product_name': 'Phone', 'amount': 'HoSA', 'status': 'Placed', 'created_at': '2026-04-20T11:01:54Z', 'updated_at': '2026-04-20T11:01:54Z'}, 'source': {'version': '2.5.4.Final', 'connector': 'mysql', 'name': 'dbserver1', 'ts_ms': 1776682914000, 'snapshot': 'false', 'db': 'testdb', 'sequence': None, 'table': 'orders', 'server_id': 1, 'gtid': None, 'file': 'mysql-bin.000006', 'pos': 852, 'row': 1, 'thread': 12, 'query': None}, 'op': 'c', 'ts_ms': 1776682915113, 'transaction': None}
# DEBUG op: c
# INSERT: {'order_id': 2, 'customer_id': 102, 'product_name': 'Phone', 'amount': 'HoSA', 'status': 'Placed', 'created_at': '2026-04-20T11:01:54Z', 'updated_at': '2026-04-20T11:01:54Z'}
# 🚨 HIGH VALUE ORDER ALERT: {'order_id': 2, 'customer_id': 102, 'product_name': 'Phone', 'amount': 'HoSA', 'status': 'Placed', 'created_at': '2026-04-20T11:01:54Z', 'updated_at': '2026-04-20T11:01:54Z'}
# [SUMMARY] Order 2 is Placed
# [CUSTOMER STREAM] Customer 102 activity
# DEBUG payload: {'before': None, 'after': {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Placed', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:24:52Z'}, 'source': {'version': '2.5.4.Final', 'connector': 'mysql', 'name': 'dbserver1', 'ts_ms': 1776684292000, 'snapshot': 'false', 'db': 'testdb', 'sequence': None, 'table': 'orders', 'server_id': 1, 'gtid': None, 'file': 'mysql-bin.000006', 'pos': 1226, 'row': 0, 'thread': 12, 'query': None}, 'op': 'c', 'ts_ms': 1776684293045, 'transaction': None}
# DEBUG op: c
# INSERT: {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Placed', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:24:52Z'}
# 🚨 HIGH VALUE ORDER ALERT: {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Placed', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:24:52Z'}
# [SUMMARY] Order 3 is Placed
# [CUSTOMER STREAM] Customer 103 activity
# DEBUG payload: {'before': {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Placed', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:24:52Z'}, 'after': {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Shipped', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:25:38Z'}, 'source': {'version': '2.5.4.Final', 'connector': 'mysql', 'name': 'dbserver1', 'ts_ms': 1776684338000, 'snapshot': 'false', 'db': 'testdb', 'sequence': None, 'table': 'orders', 'server_id': 1, 'gtid': None, 'file': 'mysql-bin.000006', 'pos': 1566, 'row': 0, 'thread': 12, 'query': None}, 'op': 'u', 'ts_ms': 1776684338619, 'transaction': None}
# DEBUG op: u
# UPDATE: {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Shipped', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:25:38Z'}
# 🚨 HIGH VALUE ORDER ALERT: {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Shipped', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:25:38Z'}
# [SUMMARY] Order 3 is Shipped
# [CUSTOMER STREAM] Customer 103 activity
# DEBUG payload: {'before': {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Shipped', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:25:38Z'}, 'after': None, 'source': {'version': '2.5.4.Final', 'connector': 'mysql', 'name': 'dbserver1', 'ts_ms': 1776684370000, 'snapshot': 'false', 'db': 'testdb', 'sequence': None, 'table': 'orders', 'server_id': 1, 'gtid': None, 'file': 'mysql-bin.000006', 'pos': 1935, 'row': 0, 'thread': 12, 'query': None}, 'op': 'd', 'ts_ms': 1776684370719, 'transaction': None}
# DEBUG op: d
# DELETE: {'order_id': 3, 'customer_id': 103, 'product_name': 'Tablet', 'amount': 'LcbA', 'status': 'Shipped', 'created_at': '2026-04-20T11:24:52Z', 'updated_at': '2026-04-20T11:25:38Z'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 18
#      15     except:
#      16         return 0
# ---> 18 for msg in consumer:
#      19     data = msg.value
#      21     payload = data.get("payload")
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/group.py:764, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     761     log.debug('poll: coordinator needs rejoin; returning early')
#     762     return {}
# --> 764 records, _ = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#     765 return records
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/fetcher.py:351, in Fetcher.fetched_records(self, max_records, update_offsets)
#     349 except Exception as e:
#     350     if not drained:
# --> 351         raise e
#     352     # To be thrown in the next call of this method
#     353     self._next_in_line_exception_metadata = ExceptionMetadata(fetched_partition, fetched_offset, e)
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/fetcher.py:345, in Fetcher.fetched_records(self, max_records, update_offsets)
#     343             fetched_partition = self._next_partition_records.topic_partition
#     344             fetched_offset = self._next_partition_records.next_fetch_offset
# --> 345             records_remaining -= self._append(drained,
#     346                                               self._next_partition_records,
#     347                                               records_remaining,
#     348                                               update_offsets)
#     349 except Exception as e:
#     350     if not drained:
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/fetcher.py:379, in Fetcher._append(self, drained, part, max_records, update_offsets)
#     376 if part.next_fetch_offset == position.offset:
#     377     log.debug("Returning fetched records at offset %d for assigned"
#     378               " partition %s", position.offset, tp)
# --> 379     part_records = part.take(max_records)
#     380     # list.extend([]) is a noop, but because drained is a defaultdict
#     381     # we should avoid initializing the default list unless there are records
#     382     if part_records:
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/fetcher.py:980, in Fetcher.PartitionRecords.take(self, n)
#     978 except Exception as e:
#     979     if not records:
# --> 980         raise e
#     981     # To be thrown in the next call of this method
#     982     self._next_inline_exception = e
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/fetcher.py:977, in Fetcher.PartitionRecords.take(self, n)
#     974 records = []
#     975 try:
#     976     # Note that records.extend(iter) will extend partially when exception raised mid-stream
# --> 977     records.extend(itertools.islice(self.record_iterator, 0, n))
#     978 except Exception as e:
#     979     if not records:
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/fetcher.py:1037, in Fetcher.PartitionRecords._unpack_records(self, tp, records, key_deserializer, value_deserializer)
#    1035 value_size = len(record.value) if record.value is not None else -1
#    1036 key = self._deserialize(key_deserializer, tp.topic, record.key)
# -> 1037 value = self._deserialize(value_deserializer, tp.topic, record.value)
#    1038 headers = record.headers
#    1039 header_size = sum(
#    1040     len(h_key.encode("utf-8")) + (len(h_val) if h_val is not None else 0) for h_key, h_val in
#    1041     headers) if headers else -1
#
# File /usr/local/lib/python3.11/site-packages/kafka/consumer/fetcher.py:1073, in Fetcher.PartitionRecords._deserialize(self, f, topic, bytes_)
#    1071 if isinstance(f, Deserializer):
#    1072     return f.deserialize(topic, bytes_)
# -> 1073 return f(bytes_)
#
# Cell In[7], line 9, in <lambda>(x)
#       2 import json
#       3 import base64
#       5 consumer = KafkaConsumer(
#       6     "dbserver1.testdb.orders",
#       7     bootstrap_servers="kafka:9092",
#       8     auto_offset_reset="earliest",
# ----> 9     value_deserializer=lambda x: json.loads(x.decode("utf-8"))
#      10 )
#      11 def decode_amount(value):
#      12     try:
#
# AttributeError: 'NoneType' object has no attribute 'decode'
